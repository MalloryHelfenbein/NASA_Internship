# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
from urllib.parse import urlencode, quote_plus
import numpy as np
import sys

import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# **Pandas Version**<br>
# Here we import pandas in a different cell because this code requires Pandas version 1.5.3<br> If the users Pandas version differs from 1.5.3 there is a 'pip install' line that should be run to ensure the proper version of Pandas.

# %%
#We designed the code to work with Pandas 1.5.3
import pandas as pd
print(pd. __version__)

#If the Pandas version differs from 1.5.3, run the following:
#pip install pandas==1.5.3 --user
# Out:
# 1.5.3

# %% [markdown]
# # **Citing this code**
# This code is the second version of a Expertise finding tool developed by Volz et al. 2023 (https://ui.adsabs.harvard.edu/abs/2023AAS...24210207V/abstract).<br>
# It utilizes NASA ADS API to query for articles (refereed or not) in the "Astronomy" database (cite ADS).
# Please, cite "Helfenbein et al. 2023 (in prep) and refer to the README file in the github.

# %% [markdown]
# **Directory set up**<br>
# The file *stopwords.txt* is utilized to create meaningful N-grams. Make sure to provide an accurate path in the following cell.<br> Also, the path will be used by the code in other instances to identify other useful files.

# %%
path_stop= 'Insert Path Here'
stop_file='stopwords.txt'
stop_dir=path_stop+stop_file
sys.path.append(path_stop)

# %%
#For the TextAnalysis File, please refer to M. Volze et al. 2023
import TextAnalysis as TA
import ADSsearcherpkg_test as AP

# %%
#token = 'Your own token from ADS API page ' #Insert your API token

# %%
datf=AP.ads_search(institution="Howard university",
               token=token, stop_dir=stop_dir)
# Out:
# I will search for every paper who first authors is afiliated with Howard university and published in the past 15 years.
#
# I am now querying ADS.

# %%
datf
# Out:
#                Input Author  \
# 0           Abdullah, Ajamu
# 1     Allen, Walter W., Jr.
# 2             Anusie, Steve
# 3               Bacha, Tulu
# 4              Blake, Ameer
# 5            Brown, Beth A.
# 6              Coley, J. B.
# 7               Coley, Joel
# 8            Coley, Joel B.
# 9            David-Uraz, A.
# 10             Dumervil, S.
# 11                 Fahr, A.
# 12         Finch, Tehani K.
# 13  Garcia-Sanchez, Raul F.
# 14           Halpern, J. B.
# 15            Howard, S. K.
# 16        Howard, Stephanie
# 17     Howard, Stephanie K.
# 18         Hubbard, Ryan J.
# 19          Hübsch, Tristan
# 20      Jenkins, Gregory S.
# 21          Lewis, J. M. T.
# 22          Lindesay, James
# 23             Mann, Ayanna
# 24       Manning, Sinclaire
# 25     Mbaye, Mamadou Thiao
# 26          McGee, Carissma
# 27                Misra, P.
# 28                Morse, Z.
# 29        Morse, Zachary R.
# 30              N'Doumi, M.
# 31                Olsen, K.
# 32              Pope, Myles
# 33             Qasim, Danna
# 34        Roi Smith, Sergio
# 35             Sakai, R. K.
# 36       Schwartzman, D. W.
# 37       Schwartzman, David
# 38       Thomas, Brianna P.
# 39      Vidaurri, Monica R.
# 40           Walker, Ashley
# 41           Weber, Tristan
# 42          Whiteman, D. N.
# 43              Wofford, A.
# 44          Yarber, Aara'L.
#
#                                     Input Institution  \
# 0                                   Howard university
# 1                                   Howard university
# 2                                   Howard university
# 3                                   Howard university
# 4                                   Howard university
# 5                Howard university, Howard university
# 6                                   Howard university
# 7                Howard university, Howard university
# 8   Howard university, Howard university, Howard u...
# 9                Howard university, Howard university
# 10                                  Howard university
# 11                                  Howard university
# 12                                  Howard university
# 13                                  Howard university
# 14                                  Howard university
# 15                                  Howard university
# 16                                  Howard university
# 17                                  Howard university
# 18                                  Howard university
# 19                                  Howard university
# 20  Howard university, Howard university, Howard u...
# 21                                  Howard university
# 22  Howard university, Howard university, Howard u...
# 23                                  Howard university
# 24               Howard university, Howard university
# 25                                  Howard university
# 26                                  Howard university
# 27                                  Howard university
# 28                                  Howard university
# 29                                  Howard university
# 30                                  Howard university
# 31                                  Howard university
# 32                                  Howard university
# 33                                  Howard university
# 34                                  Howard university
# 35                                  Howard university
# 36                                  Howard university
# 37               Howard university, Howard university
# 38  Howard university, Howard university, Howard u...
# 39                                  Howard university
# 40  Howard university, Howard university, Howard u...
# 41                                  Howard university
# 42                                  Howard university
# 43               Howard university, Howard university
# 44               Howard university, Howard university
#
#                                          First Author  \
# 0                                     Abdullah, Ajamu
# 1                               Allen, Walter W., Jr.
# 2                                       Anusie, Steve
# 3                                         Bacha, Tulu
# 4                                        Blake, Ameer
# 5                      Brown, Beth A., Brown, Beth A.
# 6                                        Coley, J. B.
# 7                            Coley, Joel, Coley, Joel
# 8      Coley, Joel B., Coley, Joel B., Coley, Joel B.
# 9                      David-Uraz, A., David-Uraz, A.
# 10                                       Dumervil, S.
# 11                                           Fahr, A.
# 12                                   Finch, Tehani K.
# 13                            Garcia-Sanchez, Raul F.
# 14                                     Halpern, J. B.
# 15                                      Howard, S. K.
# 16                                  Howard, Stephanie
# 17                               Howard, Stephanie K.
# 18                                   Hubbard, Ryan J.
# 19                                    Hübsch, Tristan
# 20  Jenkins, Gregory S., Jenkins, Gregory S., Jenk...
# 21                                    Lewis, J. M. T.
# 22  Lindesay, James, Lindesay, James, Lindesay, Ja...
# 23                                       Mann, Ayanna
# 24             Manning, Sinclaire, Manning, Sinclaire
# 25                               Mbaye, Mamadou Thiao
# 26                                    McGee, Carissma
# 27                                          Misra, P.
# 28                                          Morse, Z.
# 29                                  Morse, Zachary R.
# 30                                        N'Doumi, M.
# 31                                          Olsen, K.
# 32                                        Pope, Myles
# 33                                       Qasim, Danna
# 34                                  Roi Smith, Sergio
# 35                                       Sakai, R. K.
# 36                                 Schwartzman, D. W.
# 37             Schwartzman, David, Schwartzman, David
# 38  Thomas, Brianna P., Thomas, Brianna P., Thomas...
# 39                                Vidaurri, Monica R.
# 40  Walker, Ashley, Walker, Ashley, Walker, Ashley...
# 41                                     Weber, Tristan
# 42                                    Whiteman, D. N.
# 43                           Wofford, A., Wofford, A.
# 44                   Yarber, Aara'L., Yarber, Aara'L.
#
#                                               Bibcode  \
# 0                                 2014AAS...22324403A
# 1                                 2009PhDT.........1A
# 2                                 2019AAS...23325917A
# 3                                 2011PhDT.........7B
# 4                                 2016AAS...22713710B
# 5            2010AIPC.1280....3B, 2008CQGra..25j5026B
# 6                                 2020AAS...23545701C
# 7            2023AAS...24142807C, 2022HEAD...1940601C
# 8   2019ApJ...879...34C, 2019AAS...23323601C, 2019...
# 9            2021MNRAS.504.4841D, 2021MNRAS.501.2677D
# 10                                2020AGUFMP076.0002D
# 11                                2011epsc.conf...11F
# 12                                2009JHEP...03..145F
# 13                                2014isms.confEMJ07G
# 14                                2011AGUFM.P13A1645H
# 15                                2020AGUFMU008...06H
# 16                                2021AGUFMSM51C..06H
# 17                                2022AGUFMSM25A..05H
# 18                                2016AAS...22733403H
# 19                                2012IJMPA..2750173H
# 20  2012GeoRL..3920810J, 2008GeoRL..3512804J, 2008...
# 21                                2021JGRE..12606803L
# 22  2012FoPh...42.1573L, 2010CQGra..27u5015L, 2010...
# 23                                2023AAS...24120511M
# 24           2015AAS...22514338M, 2013AAS...22144203M
# 25                                2014PhDT.......274M
# 26                                2023AAS...24117763M
# 27                                2012AGUFM.P13A1893M
# 28                                2020AGUFMP063...02M
# 29                                2021PSJ.....2..167M
# 30                                2011AGUFM.P33A1750N
# 31                                2020AGUFMP086...02O
# 32                                2023AAS...24140126P
# 33                                2022ApJ...929..176Q
# 34                                2017AAS...22924203R
# 35                                2011AGUFM.A41A0032S
# 36                                2014AGUFM.P11C3775S
# 37           2011OLEB...41..581S, 2008AsBio...8..187S
# 38  2017AAS...22943501T, 2016AAS...22713819T, 2015...
# 39                                2022PSJ.....3..137V
# 40  2023AAS...24110401W, 2023AAS...24116201W, 2022...
# 41                                2022GeoRL..4998633W
# 42                                2020AGUFMED005..05W
# 43           2021AAS...23753511W, 2020AAS...23537712W
# 44           2015AAS...22525022Y, 2014AAS...22325219Y
#
#                                                 Title  \
# 0                      New Star Formation in NGC 3690
# 1   The canonical proper-time theory applied to pa...
# 2   The Mini-MUSCLES Treasury Survey: Measurements...
# 3   Effects of Cloud on Goddard Lidar Observatory ...
# 4   A CubeSat to Search for Transiting Planets Aro...
# 5   Causal Structures of Dynamic Black Holes, Cons...
# 6   A Study of the Extragalactic Gamma-ray Binary ...
# 7   A Study of the 2020 Type II Giant Outburst of ...
# 8   A Study of the 20 day Superorbital Modulation ...
# 9   MOBSTER - IV. Detection of a new magnetic B-ty...
# 10  Electrical Conductivity and Magnetic Induction...
# 11  Pressure Effects on Product Channels of Hydroc...
# 12  Three-charge supertubes in a rotating black ho...
# 13  Distinctions in the Raman Spectroscopy Feature...
# 14  Pressure Effects on Product Channels of the Al...
# 15  Characteristics of Ultra Low Frequency Plasma ...
# 16  Voyager 2 Magnetic Field Data Near Closest App...
# 17  Current State of a Magnetospheric Disturbance ...
# 18  Identifying Extraplanar Diffuse Ionized Gas in...
# 19  On the Construction and the Structure of Off-S...
# 20  The influence of the SAL and lightning on trop...
# 21  Pyrolysis of Oxalate, Acetate, and Perchlorate...
# 22  Self-consistent Solutions of Canonical Proper ...
# 23  Improved Model Of Optical Elements Involved In...
# 24  Probing the Magnetic Fields in the Environment...
# 25            Adsorption of Gases on Carbon Nanotubes
# 26  Dark Matter Accounts for Perturbation in the G...
# 27  Organic Contaminants Library for the Sample An...
# 28  Developing AN Augmented Reality Application fo...
# 29  Detailed Morphologic Mapping and Traverse Plan...
# 30  Radiative Lifetimes of NH<SUB>2</SUB>(\Atilde<...
# 31  Deformation along Enceladus' Tiger Stripes: In...
# 32        Accurate Masses of Extraordinary Red Giants
# 33  Radiation-induced D/H Exchange Rate Constants ...
# 34       Long-Term Timing of Globular Cluster Pulsars
# 35  Ozone Development and Destruction in the Plane...
# 36  Habitability for Complex Life and the Developm...
# 37  Multiple Paths to Encephalization and Technica...
# 38  Revisiting the Trend of Debris Disks with rega...
# 39  The Outer Edge of the Venus Zone around Main-s...
# 40  Modeling Cloud Microphysics in Ice Giant Atmos...
# 41  Updated Spherical Harmonic Magnetic Field Mome...
# 42  Planetary Boundary Layer Workshop in the Time ...
# 43  Towards the development of a STEAM rural broad...
# 44  Mapping the Star Formation in NGC 1097 Using t...
#
#                                   Publication Date  \
# 0                                       2014-01-00
# 1                                       2009-00-00
# 2                                       2019-01-00
# 3                                       2011-00-00
# 4                                       2016-01-00
# 5                           2010-10-00, 2008-05-00
# 6                                       2020-01-00
# 7                           2023-01-00, 2022-04-00
# 8               2019-07-00, 2019-01-00, 2019-01-00
# 9                           2021-07-00, 2021-02-00
# 10                                      2020-12-00
# 11                                      2011-10-00
# 12                                      2009-03-00
# 13                                      2014-06-00
# 14                                      2011-12-00
# 15                                      2020-12-00
# 16                                      2021-12-00
# 17                                      2022-12-00
# 18                                      2016-01-00
# 19                                      2012-11-00
# 20  2012-10-00, 2008-06-00, 2008-06-00, 2008-04-00
# 21                                      2021-04-00
# 22  2012-12-00, 2010-11-00, 2010-10-00, 2009-06-00
# 23                                      2023-01-00
# 24                          2015-01-00, 2013-01-00
# 25                                      2014-01-00
# 26                                      2023-01-00
# 27                                      2012-12-00
# 28                                      2020-12-00
# 29                                      2021-08-00
# 30                                      2011-12-00
# 31                                      2020-12-00
# 32                                      2023-01-00
# 33                                      2022-04-00
# 34                                      2017-01-00
# 35                                      2011-12-00
# 36                                      2014-12-00
# 37                          2011-12-00, 2008-02-00
# 38              2017-01-00, 2016-01-00, 2015-01-00
# 39                                      2022-06-00
# 40  2023-01-00, 2023-01-00, 2022-12-00, 2022-12-00
# 41                                      2022-12-00
# 42                                      2020-12-00
# 43                          2021-01-00, 2020-01-00
# 44                          2015-01-00, 2014-01-00
#
#                                              Keywords  \
# 0
# 1   Canonical proper-time, Euler-Lagrange equation...
# 2
# 3   Earth sciences, Clouds, Errors, Wind speed, Op...
# 4
# 5   black holes, space-time configurations, satell...
# 6
# 7                                                  ,
# 8   accretion, accretion disks, stars: individual:...
# 9   techniques: photometric, techniques: polarimet...
# 10  0738 Ice, CRYOSPHERE, 4299 General or miscella...
# 11
# 12  High Energy Physics - Theory, General Relativi...
# 13                     Analytical, Combustion, Plasma
# 14  5405 PLANETARY SCIENCES: SOLID SURFACE PLANETS...
# 15  0810 Post-secondary education, EDUCATION, 0815...
# 16
# 17
# 18
# 19  Supersymmetry, off-shell supermultiplets, worl...
# 20  Atmospheric Composition and Structure: Aerosol...
# 21  acetate, Mars, organic salt, oxalate, perchlor...
# 22  Quantum gravitation, Canonical gravitation, Ge...
# 23
# 24                                                 ,
# 25  Physics, Condensed Matter;Physics, Astronomy a...
# 26
# 27  1976 INFORMATICS / Software tools and services...
# 28  6207 Comparative planetology, PLANETARY SCIENC...
# 29  Lunar impacts, Lunar surface, Rovers, Lunar cr...
# 30  6000 PLANETARY SCIENCES: COMETS AND SMALL BODI...
# 31  0738 Ice, CRYOSPHERE, 4299 General or miscella...
# 32
# 33  Ice destruction, Cosmic rays, Laboratory astro...
# 34
# 35  0345 ATMOSPHERIC COMPOSITION AND STRUCTURE / P...
# 36  1605 Abrupt/rapid climate change, GLOBAL CHANG...
# 37  Biosphere, Encephalization, Temperature, Oxyge...
# 38                                               , ,
# 39  Venus, Carbon dioxide, Greenhouse gases, Habit...
# 40                                             , , ,
# 41  Ganymede, magnetic field, spherical harmonics,...
# 42  0820 Curriculum and laboratory design, EDUCATI...
# 43                                                 ,
# 44                                                 ,
#
#                                          Affiliations  \
# 0                                   Howard University
# 1                                   Howard University
# 2    Howard University, Washington, DC, United States
# 3                                   Howard University
# 4                                   Howard University
# 5   NASA Goddard Space Flight Center, Greenbelt, M...
# 6   Department of Physics, Howard University, Wash...
# 7                Howard University, Howard University
# 8   Department of Physics and Astronomy, Howard Un...
# 9   Department of Physics and Astronomy, and Barto...
# 10  Chemical Engineering, Howard University, Washi...
# 11  Howard University, Department of Chemistry, Wa...
# 12  Department of Physics and Astronomy, Howard Un...
# 13  Howard University, Department of Physics and A...
# 14       Chemistry, Howard Univ, Washington, DC, USA;
# 15   Howard University, Washington, DC, United States
# 16       Howard University, Washington, United States
# 17       Howard University, Washington, United States
# 18                                  Howard University
# 19  Department of Physics and Astronomy, Howard Un...
# 20  Department of Physics and Astronomy, Howard Un...
# 21  Department of Physics and Astronomy, Howard Un...
# 22  Computational Physics Laboratory, Howard Unive...
# 23                                  Howard University
# 24               Howard University, Howard University
# 25                                  Howard University
# 26                                  Howard University
# 27  Department of Physics &amp; Astronomy, Howard ...
# 28   Howard University, Washington, DC, United States
# 29  Department of Physics and Astronomy, Howard Un...
# 30  Chemistry, Howard University, Washington, DC, ...
# 31  Physics and Astronomy, Howard University, Wash...
# 32                                  Howard University
# 33  Astrochemistry Laboratory, NASA Goddard Space ...
# 34                                  Howard University
# 35            Howard University, Beltsville, MD, USA;
# 36  Biology, Howard University, Washington, DC, Un...
# 37  Department of Biology, Howard University, Wash...
# 38  Howard University, Howard University, Howard U...
# 39  Department of Physics and Astronomy, Howard Un...
# 40  Howard University, Howard University, Howard U...
# 41  NASA Goddard Space Flight Center, Greenbelt, M...
# 42   Howard University, Washington, DC, United States
# 43  Howard University, Washington D.c., DC, Howard...
# 44               Howard University, Howard University
#
#                                              Abstract  \
# 0   NGC 3690 is a system of merging spiral galaxie...
# 1   This research dissertation has three objective...
# 2   Astronomers are becoming more interested in fi...
# 3   The Goddard Lidar Observatory for Wind (GLOW),...
# 4   The goal of this project is to further our gro...
# 5   Dynamic space-times, especially those manifest...
# 6   We report on XMM-Newton, Nuclear Spectroscopic...
# 7   We report on Neutron Star Interior Composition...
# 8   We report on Nuclear Spectroscopic Telescope A...
# 9   In this paper, we present results from the spe...
# 10  Europa, a Galilean moon, and other icy ocean w...
# 11  Previously we had studied the kinetics and pro...
# 12  The low velocity scattering of a D0-F1 supertu...
# 13  Metal oxides are widely used in gas sensor app...
# 14  Relatively large hydrocarbon molecules (C4, C6...
# 15  Lacking a global magnetic field and atmosphere...
# 16  In August 1989, Voyager 2 became the first and...
# 17  During its time at Mars, MAVEN has observed mu...
# 18  The efficiency with which galaxies convert gas...
# 19  Recent efforts to classify representations of ...
# 20  We present results for multiple Saharan Air La...
# 21  Organic salts, such as Fe, Ca, and Mg oxalates...
# 22  Generic self-gravitating quantum solutions tha...
# 23  Large optical surveys have always been a very ...
# 24  We present a rotation measure survey of radio ...
# 25  This research focus in studying the interactio...
# 26  The longest recognized stellar stream in the M...
# 27  A library containing mass spectra for Sample A...
# 28
# 29  Schrödinger basin, a 312 km diameter complex i...
# 30  Fluorescence (X<SUP>2</SUP>B<SUB>1</SUB> ← \At...
# 31  Enceladus' Tiger Stripe fractures and their je...
# 32  Mass and radius measurements for red giant sta...
# 33  Gas-phase and solid-state chemistry in low-tem...
# 34  Pulsar timing is a powerful astrophysical tool...
# 35  During the DISCOVER-AQ experiment several plat...
# 36  We submit that the tightly coupled coevolution...
# 37  We propose consideration of at least two possi...
# 38  Finding excess infrared emission around a star...
# 39  A key item of interest for planetary scientist...
# 40  The atmospheric composition of the ice giants,...
# 41  In this study, we use data from the Juno and G...
# 42  We were funded to host a 2-week workshop in th...
# 43  Inspired by high-impact scientific results fro...
# 44  We present new C- and L-band VLA continuum obs...
#
#                                            Identifier  \
# 0                                 2014AAS...22324403A
# 1                                 2009PhDT.........1A
# 2                                 2019AAS...23325917A
# 3                                 2011PhDT.........7B
# 4                                 2016AAS...22713710B
# 5   10.1063/1.3507200, arXiv:0904.4192, 2010AIPC.1...
# 6                                 2020AAS...23545701C
# 7            2023AAS...24142807C, 2022HEAD...1940601C
# 8   2019ApJ...879...34C, arXiv:1905.08817, 2019arX...
# 9   2021MNRAS.tmp..907D, 2021MNRAS.504.4841D, 10.1...
# 10                                2020AGUFMP076.0002D
# 11           2011DPS....43...11F, 2011epsc.conf...11F
# 12  arXiv:hep-th/0612085, 10.48550/arXiv.hep-th/06...
# 13       10.15278/isms.2014.MJ07, 2014isms.confEMJ07G
# 14                                2011AGUFM.P13A1645H
# 15                                2020AGUFMU008...06H
# 16                                2021AGUFMSM51C..06H
# 17                                2022AGUFMSM25A..05H
# 18                                2016AAS...22733403H
# 19  arXiv:1202.4342, 10.1142/S0217751X12501734, 10...
# 20  2012GeoRL..3920810J, 10.1029/2012GL053532, 10....
# 21          2021JGRE..12606803L, 10.1029/2020JE006803
# 22  2011arXiv1108.4897L, 10.1007/s10701-012-9684-2...
# 23                                2023AAS...24120511M
# 24           2015AAS...22514338M, 2013AAS...22144203M
# 25                                2014PhDT.......274M
# 26                                2023AAS...24117763M
# 27                                2012AGUFM.P13A1893M
# 28                                2020AGUFMP063...02M
# 29            10.3847/PSJ/ac0728, 2021PSJ.....2..167M
# 30                                2011AGUFM.P33A1750N
# 31                                2020AGUFMP086...02O
# 32                                2023AAS...24140126P
# 33  10.3847/1538-4357/ac602b, 2022ApJ...929..176Q,...
# 34                                2017AAS...22924203R
# 35                                2011AGUFM.A41A0032S
# 36                                2014AGUFM.P11C3775S
# 37  2011OLEB..tmp...41S, 2011OLEB...41..581S, 10.1...
# 38  2017AAS...22943501T, 2016AAS...22713819T, 2015...
# 39  2022PSJ.....3..137V, 10.3847/PSJ/ac68e2, arXiv...
# 40  2023AAS...24110401W, 2023AAS...24116201W, 2022...
# 41          10.1029/2022GL098633, 2022GeoRL..4998633W
# 42                                2020AGUFMED005..05W
# 43           2021AAS...23753511W, 2020AAS...23537712W
# 44           2015AAS...22525022Y, 2014AAS...22325219Y
#
#                                          Top 10 Words  \
# 0   [(star, 5), (system, 3), (merging, 3), (galaxy...
# 1   [(equation, 6), (formulation, 5), (proper, 5),...
# 2   [(star, 9), (flare, 5), (observation, 5), (lig...
# 3   [(wind, 10), (error, 10), (glow, 9), (cloud, 8...
# 4   [(star, 6), (cubesat, 6), (disk, 4), (planet, ...
# 5   [(black, 4), (hole, 4), (diagram, 3), (dynamic...
# 6   [(ray, 6), (xmm, 4), (newton, 4), (telescope, ...
# 7   [(nustar, 10), (kev, 10), (luminosity, 10), (f...
# 8   [(superorbital, 22), (ray, 11), (minimum, 10),...
# 9   [(star, 8), (magnetic, 7), (field, 6), (result...
# 10  [(europa, 9), (ocean, 3), (electrical, 3), (co...
# 11  [(radical, 7), (reaction, 6), (product, 3), (r...
# 12  [(supertube, 4), (black, 2), (hole, 2), (case,...
# 13  [(gas, 10), (temperature, 7), (oxide, 6), (wo,...
# 14  [(radical, 8), (reaction, 8), (pressure, 5), (...
# 15  [(wave, 9), (solar, 6), (wind, 6), (magnetic, ...
# 16  [(triton, 8), (feature, 7), (neptune, 5), (voy...
# 17  [(event, 5), (disturbance, 4), (martian, 4), (...
# 18  [(galaxy, 7), (edig, 5), (gas, 3), (star, 3), ...
# 19  [(adinkras, 4), (supermultiplets, 3), (gauge, ...
# 20  [(sal, 13), (ozone, 9), (tropical, 9), (africa...
# 21  [(organic, 7), (acetate, 6), (salt, 5), (oxala...
# 22  [(quantum, 17), (gravitating, 7), (dynamic, 7)...
# 23  [(element, 6), (optical, 4), (ztf, 4), (field,...
# 24  [(galaxy, 10), (sample, 6), (observed, 6), (st...
# 25  [(adsorption, 6), (gas, 5), (nanotube, 5), (ca...
# 26  [(stream, 10), (gd, 6), (stellar, 5), (dark, 5...
# 27  [(library, 12), (spectrum, 5), (sam, 4), (mate...
# 28                                                 []
# 29  [(lunar, 9), (basin, 5), (mission, 5), (schr, ...
# 30  [(nh, 9), (state, 6), (radiative, 6), (lifetim...
# 31  [(ice, 12), (rift, 10), (stress, 7), (shelf, 6...
# 32  [(star, 6), (mass, 5), (red, 3), (giant, 3), (...
# 33  [(exchange, 6), (ice, 5), (rate, 5), (constant...
# 34  [(pulsar, 7), (timing, 6), (model, 3), (data, ...
# 35  [(ozone, 10), (day, 6), (layer, 5), (balloon, ...
# 36  [(bew, 4), (temperature, 4), (earth, 4), (life...
# 37  [(path, 4), (homeothermic, 2), (animal, 2), (s...
# 38  [(star, 10), (source, 8), (planet, 6), (observ...
# 39  [(venus, 11), (zone, 8), (planet, 6), (habitab...
# 40  [(aerosol, 21), (ice, 12), (giant, 12), (layer...
# 41  [(ganymede, 4), (data, 3), (magnetic, 3), (moo...
# 42  [(workshop, 10), (virtual, 4), (week, 3), (stu...
# 43  [(radio, 9), (flare, 6), (star, 5), (area, 4),...
# 44  [(bar, 6), (galaxy, 5), (data, 5), (star, 5), ...
#
#                                        Top 10 Bigrams  \
# 0   [((star, formation), 3), ((ngc, system), 2), (...
# 1   [((proper, time), 5), ((canonical, proper), 4)...
# 2   [((light, curve), 4), ((dwarf, star), 3), ((mi...
# 3   [((wind, speed), 4), ((atmospheric, variabilit...
# 4   [((debris, disk), 2), ((beta, pic), 2), ((smal...
# 5   [((black, hole), 4), ((large, scale), 2), ((sc...
# 6   [((xmm, newton), 4), ((light, curve), 2), ((re...
# 7   [((nicer, nustar), 6), ((neutron, star), 5), (...
# 8   [((superorbital, modulation), 8), ((minimum, m...
# 9   [((magnetic, field), 4), ((dipolar, magnetic),...
# 10  [((electrical, conductivity), 3), ((magnetic, ...
# 11  [((radical, reaction), 3), ((relevant, planeta...
# 12  [((black, hole), 2), ((angular, momentum), 2),...
# 13  [((metal, oxide), 5), ((temperature, increase)...
# 14  [((radical, reaction), 5), ((torr, kpa), 3), (...
# 15  [((solar, wind), 6), ((magnetic, field), 5), (...
# 16  [((neptune, magnetosphere), 2), ((resonance, i...
# 17  [((magnetic, field), 4), ((martian, magnetosph...
# 18  [((accretion, feedback), 2), ((feedback, proce...
# 19  [((gauge, quotient), 3), ((doran, al), 2), ((c...
# 20  [((ozone, mixing), 5), ((mixing, ratio), 5), (...
# 21  [((organic, salt), 4), ((ca, mg), 3), ((mg, ox...
# 22  [((gravitating, quantum), 4), ((black, hole), ...
# 23  [((large, optical), 2), ((optical, survey), 2)...
# 24  [((mg, ii), 3), ((star, cluster), 3), ((absorp...
# 25  [((carbon, nanotube), 2), ((explore, adsorptio...
# 26  [((stellar, stream), 5), ((dark, matter), 5), ...
# 27  [((normalization, protocol), 3), ((gcms, data)...
# 28                                                 []
# 29  [((schr, dinger), 4), ((dinger, basin), 3), ((...
# 30  [((radiative, lifetime), 6), ((electronically,...
# 31  [((ice, shelf), 6), ((stress, release), 5), ((...
# 32  [((red, giant), 3), ((giant, star), 3), ((mass...
# 33  [((rate, constant), 5), ((exchange, ice), 2), ...
# 34  [((timing, model), 3), ((model, provide), 2), ...
# 35  [((ozonesonde, tethered), 2), ((tethered, ball...
# 36  [((geologic, time), 2), ((long, term), 2), ((t...
# 37  [((homeothermic, animal), 2), ((swarm, intelli...
# 38  [((host, star), 3), ((debris, disk), 2), ((sam...
# 39  [((habitable, zone), 4), ((venus, zone), 4), (...
# 40  [((ice, giant), 12), ((aerosol, layer), 9), ((...
# 41  [((internal, magnetic), 2), ((dipole, approxim...
# 42  [((fully, virtual), 2), ((virtual, experience)...
# 43  [((optical, flare), 3), ((broader, impact), 2)...
# 44  [((star, formation), 5), ((million, year), 3),...
#
#                                       Top 10 Trigrams  \
# 0   [((ngc, system, merging), 1), ((system, mergin...
# 1   [((canonical, proper, time), 4), ((research, d...
# 2   [((muscles, treasury, survey), 2), ((astronome...
# 3   [((goddard, lidar, observatory), 2), ((lidar, ...
# 4   [((goal, project, growing), 1), ((project, gro...
# 5   [((large, scale, causal), 2), ((black, hole, p...
# 6   [((report, xmm, newton), 1), ((xmm, newton, nu...
# 7   [((fe, fluorescent, emission), 4), ((report, n...
# 8   [((superorbital, minimum, maximum), 6), ((mini...
# 9   [((dipolar, magnetic, field), 2), ((paper, pre...
# 10  [((electrical, conductivity, data), 2), ((euro...
# 11  [((previously, studied, kinetics), 1), ((studi...
# 12  [((low, velocity, scattering), 1), ((velocity,...
# 13  [((metal, oxide, gas), 2), ((wo, silicon, subs...
# 14  [((large, hydrocarbon, molecules), 1), ((hydro...
# 15  [((ultra, low, frequency), 2), ((low, frequenc...
# 16  [((august, voyager, spacecraft), 1), ((voyager...
# 17  [((martian, magnetosphere, due), 2), ((time, m...
# 18  [((accretion, feedback, processes), 2), ((effi...
# 19  [((recent, efforts, classify), 1), ((efforts, ...
# 20  [((ozone, mixing, ratios), 3), ((middle, upper...
# 21  [((organic, salts, fe), 1), ((salts, fe, ca), ...
# 22  [((geometries, horizons, offer), 2), ((horizon...
# 23  [((large, optical, surveys), 2), ((wide, field...
# 24  [((star, formation, induced), 2), ((present, r...
# 25  [((consequence, heat, capacity), 2), ((researc...
# 26  [((gd, stellar, stream), 2), ((longest, recogn...
# 27  [((library, mass, spectra), 1), ((mass, spectr...
# 28                                                 []
# 29  [((schr, dinger, basin), 3), ((dinger, basin, ...
# 30  [((electronically, excited, state), 3), ((radi...
# 31  [((enceladus, tiger, stripe), 2), ((tiger, str...
# 32  [((red, giant, stars), 3), ((mass, radius, mea...
# 33  [((gas, phase, solid), 1), ((phase, solid, sta...
# 34  [((timing, models, provide), 2), ((models, pro...
# 35  [((ozonesonde, tethered, balloon), 2), ((disco...
# 36  [((submit, tightly, coupled), 1), ((tightly, c...
# 37  [((propose, consideration, evolutionary), 1), ...
# 38  [((percent, frequency, sources), 2), ((frequen...
# 39  [((outer, edge, venus), 2), ((edge, venus, zon...
# 40  [((atmospheric, composition, ice), 3), ((compo...
# 41  [((study, data, juno), 1), ((data, juno, galil...
# 42  [((fully, virtual, experience), 2), ((funded, ...
# 43  [((radio, bursts, optical), 2), ((bursts, opti...
# 44  [((present, band, vla), 1), ((band, vla, conti...
#
#                      Data Type
# 0                        Clean
# 1                        Dirty
# 2                        Clean
# 3                        Dirty
# 4                        Clean
# 5                 Dirty, Dirty
# 6                        Clean
# 7                 Clean, Dirty
# 8          Clean, Clean, Clean
# 9                 Clean, Clean
# 10                       Dirty
# 11                       Dirty
# 12                       Dirty
# 13                       Dirty
# 14                       Dirty
# 15                       Dirty
# 16                       Dirty
# 17                       Dirty
# 18                       Clean
# 19                       Dirty
# 20  Dirty, Dirty, Dirty, Dirty
# 21                       Dirty
# 22  Dirty, Dirty, Dirty, Dirty
# 23                       Clean
# 24                Clean, Clean
# 25                       Dirty
# 26                       Clean
# 27                       Dirty
# 28                       Dirty
# 29                       Dirty
# 30                       Dirty
# 31                       Dirty
# 32                       Clean
# 33                       Clean
# 34                       Clean
# 35                       Dirty
# 36                       Dirty
# 37                Dirty, Dirty
# 38         Clean, Clean, Clean
# 39                       Dirty
# 40  Clean, Clean, Dirty, Dirty
# 41                       Dirty
# 42                       Dirty
# 43                Clean, Clean
# 44                Clean, Clean

# %% [markdown]
# # **Example 1: Searching expertises of a single person based on their name**

# %% [markdown]
# The search will focus on papers published by a specific author in the past 15 years independently of the current affiliation:<br>
# The format for a single author search is as follows: **"Last, First"**<br>
# In the following example we search for Dr. Joshua Pepper expertise. <br>
# **Note:** the user can decide to query ONLY refereed paper adding, before the token keyword the following keyword:<br>
# **refereed="property:refereed"**

# %%
datf=AP.ads_search(name="Pepper, Joshua",
               token=token, stop_dir=stop_dir)
# Out:
# I will search for any first author publications by Pepper, Joshua in the last 15 years.
#
# I am now querying ADS.
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg_test.py:165: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the function.
#   merged= df.groupby('Input Author').aggregate({'Input Institution':', '.join,
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-fd27a9069807> in <cell line: 1>()
# ----> 1 datf=AP.ads_search(name="Pepper, Joshua",
#       2                token=token, stop_dir=stop_dir)
#
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg_test.py in ads_search(name, institution, year, refereed, token, stop_dir)
#     479     ######################## Block that runs the other functions to get the N-grams
#     480   data2= data_type(df)
# --> 481   data3= merge(data2)
#     482   data4= n_grams(data3, stop_dir)
#     483
#
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg_test.py in merge(df)
#     163     df.fillna('None', inplace=True)
#     164
# --> 165     merged= df.groupby('Input Author').aggregate({'Input Institution':', '.join,
#     166                                                   'First Author':', '.join,
#     167                                                   'Bibcode':', '.join,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     893
#     894         op = GroupByApply(self, func, args, kwargs)
# --> 895         result = op.agg()
#     896         if not is_dict_like(func) and result is not None:
#     897             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     170
#     171         if is_dict_like(arg):
# --> 172             return self.agg_dict_like()
#     173         elif is_list_like(arg):
#     174             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     502         else:
#     503             # key used for column selection and output
# --> 504             results = {
#     505                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506             }
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in <dictcomp>(.0)
#     503             # key used for column selection and output
#     504             results = {
# --> 505                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506             }
#     507
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     295
#     296             try:
# --> 297                 return self._python_agg_general(func, *args, **kwargs)
#     298             except KeyError:
#     299                 # TODO: KeyError is raised in _python_agg_general,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, raise_on_typeerror, *args, **kwargs)
#    1693
#    1694         if not output:
# -> 1695             return self._python_apply_general(f, self._selected_obj)
#    1696
#    1697         return self._wrap_aggregated_output(output)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1627             data after applying f
#    1628         """
# -> 1629         values, mutated = self.grouper.apply(f, data, self.axis)
#    1630         if not_indexed_same is None:
#    1631             not_indexed_same = mutated or self.mutated
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     837             # group might be modified
#     838             group_axes = group.axes
# --> 839             res = f(group)
#     840             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841                 mutated = True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1666     def _python_agg_general(self, func, *args, raise_on_typeerror=False, **kwargs):
#    1667         func = com.is_builtin_func(func)
# -> 1668         f = lambda x: func(x, *args, **kwargs)
#    1669
#    1670         # iterate through "columns" ex exclusions to populate output dict
#
# TypeError: sequence item 0: expected str instance, list found

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")
# Out:
#      Input Author                                  Input Institution  \
# 0  Pepper, Joshua  None, None, None, None, None, None, None, None...
#
#                                         First Author  \
# 0  Pepper, Joshua, Pepper, Joshua, Pepper, Joshua...
#
#                                              Bibcode  \
# 0  2021plat.confE..96P, 2021tsc2.confE.139P, 2020...
#
#                                                Title  \
# 0  The TESS Input Catalog and lessons for PLATO, ...
#
#                                     Publication Date  \
# 0  2021-10-00, 2021-07-00, 2020-06-00, 2020-01-00...
#
#                                             Keywords  \
# 0  Input catalogue, TESS, Zenodo community plato2...
#
#                                         Affiliations  \
# 0  Lehigh University, Lehigh University, Departme...
#
#                                             Abstract  \
# 0  The presentation compares the input catalogues...
#
#                                         Top 10 Words  \
# 0  [(star, 78), (kelt, 62), (planet, 46), (transi...
#
#                                       Top 10 Bigrams  \
# 0  [((radial, velocity), 18), ((transiting, plane...
#
#                                      Top 10 Trigrams  \
# 0  [((transiting, planets, bright), 6), ((planets...
#
#                                            Data Type
# 0  Dirty, Dirty, Clean, Dirty, Clean, Clean, Clea...

# %% [markdown]
# # **Example 2: Searching expertises of ALL scientists that published as first authors when affiliated to single institution name**

# %% [markdown]
# The search will focus on papers and all authors that have published in the past 15 years at a specific institution (academic or otherwise): <br>
# The format for a single institution is as follows: **institution="Institution Name"**. <br>
# **Caveat**: It is possible that the institutions as input by the user does not match what has been cataloged in ADS, therefore if the final output is empty, make sure to try different versions of the institution names (e.g. Cal Poly Pomona, Cal Poly, California Polytechnic State University) to get the most complete list of authors.

# %%
datf=AP.ads_search(institution="Hampton University",refereed="property:refereed",
               token=token, stop_dir=stop_dir)
# Out:
# I will search for every paper who first authors is afiliated with Hampton University and published in the past 15 years.
#
# I am now querying ADS.

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-1c1d64d39c8b> in <cell line: 2>()
#       1 # To display the data frame run the following:
# ----> 2 datf
#       3 # To save it in a excel format run the following:
#       4 #datf.to_excel(path_stop+"output.xlsx")
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-3> in __call__(self, obj)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __repr__(self)
#    1062
#    1063         repr_params = fmt.get_dataframe_repr_params()
# -> 1064         return self.to_string(**repr_params)
#    1065
#    1066     def _repr_html_(self) -> str | None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1243                 decimal=decimal,
#    1244             )
# -> 1245             return fmt.DataFrameRenderer(formatter).to_string(
#    1246                 buf=buf,
#    1247                 encoding=encoding,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_string(self, buf, encoding, line_width)
#    1134
#    1135         string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136         string = string_formatter.to_string()
#    1137         return save_to_buffer(string, buf=buf, encoding=encoding)
#    1138
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/string.py in to_string(self)
#      28
#      29     def to_string(self) -> str:
# ---> 30         text = self._get_string_representation()
#      31         if self.fmt.should_show_dimensions:
#      32             text = "".join([text, self.fmt.dimensions_info])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/string.py in _get_string_representation(self)
#      43             return self._empty_info_line
#      44
# ---> 45         strcols = self._get_strcols()
#      46
#      47         if self.line_width is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/string.py in _get_strcols(self)
#      34
#      35     def _get_strcols(self) -> list[list[str]]:
# ---> 36         strcols = self.fmt.get_strcols()
#      37         if self.fmt.is_truncated:
#      38             strcols = self._insert_dot_separators(strcols)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in get_strcols(self)
#     615         Render a DataFrame to a list of columns (as lists of strings).
#     616         """
# --> 617         strcols = self._get_strcols_without_index()
#     618
#     619         if self.index:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in _get_strcols_without_index(self)
#     881                 int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882             )
# --> 883             fmt_values = self.format_col(i)
#     884             fmt_values = _make_fixed_width(
#     885                 fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in format_col(self, i)
#     895         frame = self.tr_frame
#     896         formatter = self._get_formatter(i)
# --> 897         return format_array(
#     898             frame.iloc[:, i]._values,
#     899             formatter,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#    1329
#    1330
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in get_result(self)
#    1357
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#    1361
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in _format_strings(self)
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in _format(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#    1403
#    1404         vals = extract_array(self.values, extract_numpy=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     220         )
#     221     elif is_sequence(thing) and _nest_lvl < get_option("display.pprint_nest_depth"):
# --> 222         result = _pprint_seq(
#     223             thing,
#     224             _nest_lvl,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in _pprint_seq(seq, _nest_lvl, max_seq_items, **kwds)
#     117     s = iter(seq)
#     118     # handle sets, no slicing
# --> 119     r = [
#     120         pprint_thing(next(s), _nest_lvl + 1, max_seq_items=max_seq_items, **kwds)
#     121         for i in range(min(nitems, len(seq)))
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in <listcomp>(.0)
#     118     # handle sets, no slicing
#     119     r = [
# --> 120         pprint_thing(next(s), _nest_lvl + 1, max_seq_items=max_seq_items, **kwds)
#     121         for i in range(min(nitems, len(seq)))
#     122     ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     220         )
#     221     elif is_sequence(thing) and _nest_lvl < get_option("display.pprint_nest_depth"):
# --> 222         result = _pprint_seq(
#     223             thing,
#     224             _nest_lvl,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in _pprint_seq(seq, _nest_lvl, max_seq_items, **kwds)
#     117     s = iter(seq)
#     118     # handle sets, no slicing
# --> 119     r = [
#     120         pprint_thing(next(s), _nest_lvl + 1, max_seq_items=max_seq_items, **kwds)
#     121         for i in range(min(nitems, len(seq)))
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in <listcomp>(.0)
#     118     # handle sets, no slicing
#     119     r = [
# --> 120         pprint_thing(next(s), _nest_lvl + 1, max_seq_items=max_seq_items, **kwds)
#     121         for i in range(min(nitems, len(seq)))
#     122     ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     220         )
#     221     elif is_sequence(thing) and _nest_lvl < get_option("display.pprint_nest_depth"):
# --> 222         result = _pprint_seq(
#     223             thing,
#     224             _nest_lvl,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py in _pprint_seq(seq, _nest_lvl, max_seq_items, **kwds)
#     113         nitems = len(seq)
#     114     else:
# --> 115         nitems = max_seq_items or get_option("max_seq_items") or len(seq)
#     116
#     117     s = iter(seq)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     261
#     262     def __call__(self, *args, **kwds) -> T:
# --> 263         return self.__func__(*args, **kwds)
#     264
#     265     # error: Signature of "__doc__" incompatible with supertype "object"
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _get_option(pat, silent)
#     133
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     136
#     137     # walk the nested dict
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#     115
#     116 def _get_single_key(pat: str, silent: bool) -> str:
# --> 117     keys = _select_options(pat)
#     118     if len(keys) == 0:
#     119         if not silent:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _select_options(pat)
#     592         return keys
#     593
# --> 594     return [k for k in keys if re.search(pat, k, re.I)]
#     595
#     596
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in <listcomp>(.0)
#     592         return keys
#     593
# --> 594     return [k for k in keys if re.search(pat, k, re.I)]
#     595
#     596
#
# /usr/lib/python3.10/re.py in search(pattern, string, flags)
#     198     """Scan through string looking for a match to the pattern, returning
#     199     a Match object, or None if no match was found."""
# --> 200     return _compile(pattern, flags).search(string)
#     201
#     202 def sub(pattern, repl, string, count=0, flags=0):
#
# KeyboardInterrupt:

# %% [markdown]
# # **Example 3: Searching a single author publication while affiliated to a specific institution**

# %% [markdown]
# The search will focus on papers published by a single author while they are affiliated to a specific institution, in the past 15 years:<br>
#
# The format for a single author and institution is as follows: **name= 'Last, First', institution= 'Institution Name'**.

# %%
datf=AP.ads_search(name= 'Capper, Daniel', institution="University of Southern Mississippi",
               token=token, stop_dir=stop_dir)

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")

# %% [markdown]
# # **Example 4: Searching a single author name within a different time-frame**

# %% [markdown]
# The search will focus on papers from one single author that were published in a different time-frame. There are two options for doing so:
#    - A single year (e.g. 2010): in this case the code will query ADS for articles published by the specified authors between one year prior to 4  years after. So searching year='2010' will search articles between 2009 and 2014<br>
#    - A year range: in this case the syntax is year='[YEAR TO YEAR]' (e.g. year='[2009 TO 2023]') <br>
#
# The format for a single author name remains the same as before: **name= 'Last, First'**. <br>
#
# Here are two examples:
#     - Searching for Dr. Pepper's articles between year 1999 and 2004
#     - Searching for Dr. Pepper's articles between year 2019 and 2023

# %%
datf=AP.ads_search(name= 'Pepper, Joshua', year='2000',
               token=token, stop_dir=stop_dir)

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")

# %%
datf=AP.ads_search(name= 'Pepper, Joshua', year='[2019 TO 2023]',
               token=token, stop_dir=stop_dir)

# %%
datf

# %% [markdown]
# # **Example 5: Searching a single institution name within a specific time-frame**

# %% [markdown]
# The search will focus on authors that publishes as first authors affiliated to a specific institution in a defined timespan. <br>
# The format for a author name is the same in previous example (**"Last name, First name"**) and specified year range is similar to the option provided earlier:<br>
#    - A single year (e.g. 2010): in this case the code will query ADS for articles published by the specified authors between one year prior to 4  years after. So searching year='2010' will search articles between 2009 and 2014<br>
#    - A year range: in this case the syntax is year='[YEAR TO YEAR]' (e.g. year='[2009 TO 2023]') <br>
#
# Following we present two examples:

# %%
datf=AP.ads_search(institution="University of Southern Mississippi",year='2000',
               token=token, stop_dir=stop_dir)

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")

# %%
datf=AP.ads_search(institution="University of Southern Mississippi",year='[1990 TO 2000]',
               token=token, stop_dir=stop_dir)

# %%
datf

# %% [markdown]
# # **Example 6: Searching a single Author, at a specific institution and within a specific time-frame**

# %% [markdown]
# The following example combines several of the previous ones in a single search.
# Specifically:<br>
#    - A single author<br>
#    - Affiliated to a single institutions<br>
#    - In a specific time frame of publications<br>
#
# Please, refer to the previous examples for the sintax required. <br>
# Here are an example

# %%
datf=AP.ads_search(name= 'Brown, Beth A.', institution="Howard university",year='[2009 TO 2022]',
               token=token, stop_dir=stop_dir)

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")

# %% [markdown]
# # **Example 7: Searching through a list of institutions**

# %% [markdown]
# The search will focus on papers from a list of institutions, so the input is a csv file that has multiple institution names stored in it. This will then find all papers from those institutions (**see CAVEATS in Example 2 above related to Institution Names)**:<br>
#
# The input file has to be a .csv file (e.g."top10inst.csv"), and must contain at least one column titled  **"Current Institution"** or **"Institution"** (the first cell of the column is usually interpreted as such). The file can contains other columns, they will be ignored.<br>
# If the file is in a different directory than the one where the code it, include the whole path. <br>
#
# The code will run as in Example 2 above for each institutions and append the results at each iteration providing a final dataframe with all the researchers at all the institutions in the list provided.<br>
# **NOTE: at the moment if an institution query returns an empty dataframe the code will ignore it and continue to the following one.**

# %%
datf=AP.run_file_insts(filename= '/example3.csv',
               token=token, stop_dir=stop_dir)
# Out:
# I will search for every paper who first authors is afiliated with University of California, Berkeley and published in the past 15 years.
#
# I am now querying ADS.
#
# DataFrame is empty! Something is wrong with the institution
# I am querying ADS in a different way, stay tuned!/n
# I will search for every paper who first authors is afiliated with University of California, Berkeley and published in the past 15 years.
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg.py:122: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df= final_df.append(data1, ignore_index= True)
# 1 iterations done
# I will search for every paper who first authors is afiliated with Hunter College and published in the past 15 years.
#
# I am now querying ADS.
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg.py:122: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df= final_df.append(data1, ignore_index= True)
# 2 iterations done
# I will search for every paper who first authors is afiliated with Yale University  and published in the past 15 years.
#
# I am now querying ADS.
#
# DataFrame is empty! Something is wrong with the institution
# I am querying ADS in a different way, stay tuned!/n
# I will search for every paper who first authors is afiliated with Yale University  and published in the past 15 years.
#
# 3 iterations done
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg.py:122: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df= final_df.append(data1, ignore_index= True)

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")
# Out:
#                  Input Author                   Input Institution  \
# 0         Abdurashidova, Zara  University of California, Berkeley
# 1          Abdurrahman, F. N.  University of California, Berkeley
# 2      Abdurrahman, Fatima N.  University of California, Berkeley
# 3       Abrahams, Ellianna S.  University of California, Berkeley
# 4            Aczel, Miriam R.  University of California, Berkeley
# ...                       ...                                 ...
# 1884       van Dokkum, Pieter                    Yale University
# 1885    van Dokkum, Pieter G.                    Yale University
# 1886     van de Voort, Freeke                    Yale University
# 1887     van den Bosch, Frank                    Yale University
# 1888  van den Bosch, Frank C.                    Yale University
#
#                                            First Author  \
# 0              Abdurashidova, Zara, Abdurashidova, Zara
# 1                                    Abdurrahman, F. N.
# 2        Abdurrahman, Fatima N., Abdurrahman, Fatima N.
# 3                                 Abrahams, Ellianna S.
# 4                                      Aczel, Miriam R.
# ...                                                 ...
# 1884  van Dokkum, Pieter, van Dokkum, Pieter, van Do...
# 1885  van Dokkum, Pieter G., van Dokkum, Pieter G., ...
# 1886  van de Voort, Freeke, van de Voort, Freeke, va...
# 1887  van den Bosch, Frank, van den Bosch, Frank, va...
# 1888  van den Bosch, Frank C., van den Bosch, Frank ...
#
#                                                 Bibcode  \
# 0              2022ApJ...925..221A, 2022ApJ...924...51A
# 1                                   2018AJ....156..100A
# 2              2021ApJ...912..146A, 2021PhDT.........6A
# 3                                   2022ApJ...938...46A
# 4                                   2021ConPh..62...52A
# ...                                                 ...
# 1884  2023NatAs...7..514V, 2023RNAAS...7...83V, 2023...
# 1885  2015ApJ...813...23V, 2015ApJ...804L..26V, 2015...
# 1886  2020MNRAS.494.4867V, 2019MNRAS.482L..85V, 2018...
# 1887  2023DDA....5420004V, 2019atp..prop...59V, 2017...
# 1888  2019MNRAS.488.4984V, 2018MNRAS.475.4066V, 2018...
#
#                                                   Title  \
# 0     First Results from HERA Phase I: Upper Limits ...
# 1     Improved Image Quality over 10‧ Fields with th...
# 2     On the Possibility of Stellar Lenses in the Bl...
# 3     Informing the Cataclysmic Variable Sequence fr...
# 4     The cosmos: astronomy in the new millennium, 5...
# ...                                                 ...
# 1884  An exciting era of exploration, A Direct Conne...
# 1885  Forming Compact Massive Galaxies, Spectroscopi...
# 1886  Neutron star mergers and rare core-collapse su...
# 1887  On the Tidal Evolution of Dark Matter Substruc...
# 1888  Basilisk: Bayesian hierarchical inference of t...
#
#                                        Publication Date  \
# 0                                2022-02-00, 2022-01-00
# 1                                            2018-09-00
# 2                                2021-05-00, 2021-00-00
# 3                                            2022-10-00
# 4                                            2021-01-00
# ...                                                 ...
# 1884  2023-05-00, 2023-05-00, 2023-05-00, 2023-04-00...
# 1885  2015-11-00, 2015-05-00, 2015-01-00, 2014-12-00...
# 1886  2020-06-00, 2019-01-00, 2018-06-00, 2018-05-00...
# 1887                 2023-09-00, 2019-00-00, 2017-00-00
# 1888  2019-10-00, 2018-04-00, 2018-03-00, 2017-06-00...
#
#                                                Keywords  \
# 0     1383, 343, 1858, Astrophysics - Cosmology and ...
# 1     instrumentation: adaptive optics, site testing...
# 2     Gravitational microlensing, High-resolution mi...
# 3     Cataclysmic variable stars, Variable stars, Su...
# 4
# ...                                                 ...
# 1884  , Supermassive black holes, 1663, Astrophysics...
# 1885  galaxies: evolution, galaxies: structure, Astr...
# 1886  methods: numerical, stars: abundances, stars: ...
# 1887                                               , ,
# 1888  methods: analytical, methods: statistical, gal...
#
#                                            Affiliations  \
# 0     Department of Astronomy, University of Califor...
# 1     Department of Astronomy, University of Califor...
# 2     Department of Astronomy, University of Califor...
# 3     Department of Astrophysics, University of Cali...
# 4     California Institute for Energy and Environmen...
# ...                                                 ...
# 1884  Astronomy Department, Yale University, New Hav...
# 1885  Department of Astronomy, Yale University, New ...
# 1886  Max Planck Institute for Astrophysics, Karl-Sc...
# 1887  Yale University, Yale University, Yale University
# 1888  Department of Astronomy, Yale University, P.O....
#
#                                                Abstract  \
# 0     We report upper limits on the Epoch of Reioniz...
# 1     ´Imaka is a ground-layer adaptive optics (GLAO...
# 2     Although stellar-mass black holes (BHs) are li...
# 3     The orbital-period (P <SUB>orb</SUB>) gap in t...
# 4
# ...                                                 ...
# 1884  Long-exposure spectra taken with the James Web...
# 1885  In this paper we study a key phase in the form...
# 1886  We use cosmological, magnetohydrodynamical sim...
# 1887  The statistics of dark matter (DM) substructur...
# 1888  We present a Bayesian hierarchical inference f...
#
#                                            Top 10 Words  \
# 0     [(limit, 9), (hera, 7), (radio, 5), (upper, 4)...
# 1     [(ao, 8), (field, 5), (psf, 4), (telescope, 3)...
# 2     [(lens, 20), (field, 12), (source, 11), (image...
# 3     [(cv, 6), (orb, 4), (color, 4), (period, 3), (...
# 4                                                    []
# ...                                                 ...
# 1884  [(galaxy, 187), (cluster, 61), (mass, 58), (ng...
# 1885  [(galaxy, 114), (mass, 64), (stellar, 40), (st...
# 1886  [(gas, 29), (galaxy, 28), (star, 16), (mass, 1...
# 1887  [(halo, 29), (galaxy, 29), (matter, 27), (dark...
# 1888  [(subhaloes, 30), (halo, 27), (galaxy, 25), (m...
#
#                                          Top 10 Bigrams  \
# 0     [((upper, limit), 4), ((epoch, reionization), ...
# 1     [((ao, psf), 3), ((ao, ao), 2), ((delivered, i...
# 2     [((lens, source), 8), ((black, hole), 6), ((pr...
# 3     [((absolute, magnitude), 3), ((orbital, period...
# 4                                                    []
# ...                                                 ...
# 1884  [((globular, cluster), 44), ((dark, matter), 3...
# 1885  [((stellar, mass), 18), ((massive, galaxy), 13...
# 1886  [((star, formation), 8), ((gas, accretion), 8)...
# 1887  [((dark, matter), 26), ((halo, mass), 7), ((ma...
# 1888  [((host, halo), 8), ((dark, matter), 8), ((sat...
#
#                                         Top 10 Trigrams  \
# 0     [((cm, power, spectrum), 2), ((hydrogen, epoch...
# 1     [((delivered, image, quality), 2), ((imaka, gr...
# 2     [((eliminate, possibility, stellar), 4), ((ste...
# 3     [((color, absolute, magnitude), 2), ((dwarf, n...
# 4                                                    []
# ...                                                 ...
# 1884  [((low, surface, brightness), 10), ((hubble, s...
# 1885  [((early, type, galaxies), 7), ((star, forming...
# 1886  [((rare, core, collapse), 3), ((metal, poor, s...
# 1887  [((dark, matter, halos), 6), ((dark, matter, s...
# 1888  [((galaxy, halo, connection), 3), ((dark, matt...
#
#                                               Data Type
# 0                                          Clean, Clean
# 1                                                 Clean
# 2                                          Clean, Dirty
# 3                                                 Clean
# 4                                                 Dirty
# ...                                                 ...
# 1884  Dirty, Clean, Dirty, Clean, Clean, Dirty, Dirt...
# 1885  Clean, Clean, Clean, Clean, Clean, Clean, Clea...
# 1886                  Clean, Clean, Clean, Clean, Clean
# 1887                                Dirty, Dirty, Dirty
# 1888  Clean, Clean, Clean, Clean, Clean, Clean, Clea...
#
# [1889 rows x 13 columns]

# %% [markdown]
# # **Example 8: Searching through a list of Authors names**

# %% [markdown]
# The search will focus on papers from a list of authors names (similar format as Example 1 above, **'Last, First'**). <br>
# The input is a .csv file that has multiple authors names stored in it under a column Title: **"Name"**. <br>
# The ADS search will focus on the period 2003 to 2023.
# <br>
# If the file is in a different directory than the one where the code it, include the whole path. <br>
#
# The code will then execute the search one name after the other and uppend each result to the previous one.<br>
# In the following example we use, for convenience, the same example file as before which also contain a list of researchers names.

# %%
datf=AP.run_file_names(filename= '\example3.csv',
               token=token, stop_dir=stop_dir)
# Out:
# I will go through each name in the list. Name should be formatted in a single column called "Last, First".  We will search by default any pubblication in the past 20 years by these authors, independently of the institutions they were  affiliated to.
#
# Browning, Matthew
# I will search for every paper who first authors is Browning, Matthew and has published between 2003 and 2023.
#
# I am now querying ADS.
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg.py:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df= final_df.append(data1, ignore_index= True)
# 1 iterations done
# Cruz, Kelle
# I will search for every paper who first authors is Cruz, Kelle and has published between 2003 and 2023.
#
# I am now querying ADS.
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg.py:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df= final_df.append(data1, ignore_index= True)
# 2 iterations done
# Gawiser, Eric
# I will search for every paper who first authors is Gawiser, Eric and has published between 2003 and 2023.
#
# I am now querying ADS.
#
# 3 iterations done
# /content/drive/MyDrive/Colab Notebooks/Mallory/ADSsearcherpkg.py:150: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df= final_df.append(data1, ignore_index= True)

# %%
# To display the data frame run the following:
datf
# To save it in a excel format run the following:
#datf.to_excel(path_stop+"output.xlsx")
# Out:
#         Input Author                                  Input Institution  \
# 0  Browning, Matthew  None, None, None, None, None, None, None, None...
# 1        Cruz, Kelle  None, None, None, None, None, None, None, None...
# 2      Gawiser, Eric  None, None, None, None, None, None, None, None...
#
#                                         First Author  \
# 0  Browning, M. K., Browning, Matthew K., Brownin...
# 1  Cruz, Kelle, Cruz, K. L., Cruz, Kelle, Cruz, K...
# 2  Gawiser, Eric, Gawiser, Eric, Gawiser, Eric, G...
#
#                                              Bibcode  \
# 0  2021csss.confE..80B, 2020mdps.conf..141B, 2019...
# 1  2021csss.confE.248C, 2018yCat..51550034C, 2018...
# 2  2023AAS...24142705G, 2021adap.prop..169G, 2018...
#
#                                                Title  \
# 0  Modelling X-ray and radio emission from a flar...
# 1  SIMPLE Archive of Complex Objects: A new colla...
# 2  ODIN: Blobs, Galaxies, and Protoclusters Found...
#
#                                     Publication Date  \
# 0  2021-03-00, 2020-01-00, 2019-05-00, 2017-05-00...
# 1  2021-03-00, 2018-09-00, 2018-07-00, 2018-01-00...
# 2  2023-01-00, 2021-00-00, 2018-01-00, 2016-06-00...
#
#                                             Keywords  \
# 0  Young stars, Flares, Radio emission, , Astroph...
# 1  Very low mass stars, Astronomy, archives, Star...
# 2  , , , , , , , , , , , , , , , 98.62.Ai, 98.62....
#
#                                         Affiliations  \
# 0  Uni of Manchester, -, -, University of Exeter,...
# 1  CUNY Hunter College, -, -, Department of Physi...
# 2  Rutgers University, Rutgers University, New Br...
#
#                                             Abstract  \
# 0  T-Tauri stars exhibit strong flaring activity....
# 1  The SIMPLE Archive project -- the Substellar a...
# 2  We present a new NOIRLab Survey called ODIN (O...
#
#                                         Top 10 Words  \
# 0  [(field, 88), (magnetic, 66), (rotation, 64), ...
# 1  [(dwarf, 120), (mass, 44), (brown, 44), (low, ...
# 2  [(galaxy, 161), (formation, 75), (star, 67), (...
#
#                                       Top 10 Bigrams  \
# 0  [((magnetic, field), 42), ((differential, rota...
# 1  [((brown, dwarf), 44), ((ultracool, dwarf), 20...
# 2  [((star, formation), 57), ((formation, rate), ...
#
#                                      Top 10 Trigrams  \
# 0  [((magnetic, dynamo, action), 9), ((low, mass,...
# 1  [((stars, brown, dwarfs), 9), ((low, mass, sta...
# 2  [((star, formation, rate), 18), ((star, format...
#
#                                            Data Type
# 0  Dirty, Dirty, Dirty, Dirty, Dirty, Dirty, Dirt...
# 1  Dirty, Dirty, Dirty, Dirty, Clean, Dirty, Dirt...
# 2  Clean, Dirty, Clean, Dirty, Dirty, Dirty, Dirt...
